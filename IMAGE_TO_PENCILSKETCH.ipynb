# %% [markdown]
# IMPORT LIBRARY

# %%
import cv2

# %%
image = cv2.imread("flower.jpg")
#image

# %% [markdown]
# READ THE IMAGE IN RGB FORMAT

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# CREATE A NEW IMAGE BY CONVERTING TO GRAYSCALE

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[206, 206, 206, ..., 228, 228, 228],
#        [206, 206, 206, ..., 228, 228, 228],
#        [206, 206, 206, ..., 228, 228, 228],
#        ...,
#        [188, 187, 186, ..., 202, 202, 203],
#        [188, 187, 186, ..., 201, 201, 201],
#        [189, 188, 187, ..., 199, 200, 200]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %% [markdown]
# INVERTING IMAGE

# %%
inverted_image = 255 - gray_image
#inverted_image = cv2.bitwise_not(gray_image)
plt.imshow(inverted_image)

# %% [markdown]
# BLUR THE IMAGE BY USING THE GAUSSIAN FUNCTION

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
plt.imshow(blurred)

# %% [markdown]
# INVERT THE BLURRED IMAGE FOR FINAL IMAGE (PENCIL SKETCH)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.imshow(pencil_sketch)

# %% [markdown]
# THANKYOU!!
